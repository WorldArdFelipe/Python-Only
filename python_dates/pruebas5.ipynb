# %%
import pandas as ps
import dates_module as dm
import random as rm

# %matplotlib inline

NAME_ARCHIVE = "EMPRENDEDORES_-_PUENTE_NACIONAL.csv"


dates = dm.load_archive(NAME_ARCHIVE,"csv")
dm.set_value_is_na(dates['EDAD EN AÑOS'],dm.get_dates_three_cuartil(dates["EDAD EN AÑOS"]))
dates = dm.set_convert_dtypes(dates,{"EDAD EN AÑOS": int})



#dm.get_dates_duplicated(dates)

dates.head(15)
# Out:
#     CONSECUTIVO                 NOMBRE              TIPO DE EMPRENDIMIENTO  \
# 0             1   EMPRENDEDOR NUMERO 1                           PISCICOLA
# 1             2   EMPRENDEDOR NUMERO 2           CULTIVO Y VENTA DE TOMATE
# 2             3   EMPRENDEDOR NUMERO 3             ELECTRICIDAD AUTOMOTRIZ
# 3             4   EMPRENDEDOR NUMERO 4                           PANADERIA
# 4             5   EMPRENDEDOR NUMERO 5                          INDUSTRIAL
# 5             6   EMPRENDEDOR NUMERO 6                  COCINAS INTEGRALES
# 6             7   EMPRENDEDOR NUMERO 7                  PANADERIA Y DULCES
# 7             8   EMPRENDEDOR NUMERO 8             FABRICACION DE POCILLOS
# 8             9   EMPRENDEDOR NUMERO 9  FABRICA PRODUCTOS DE SOYA ( QUESO)
# 9            10  EMPRENDEDOR NUMERO 10                ARTESANIAS EN MADERA
# 10           11  EMPRENDEDOR NUMERO 11    VENTA DE ACCESORIOS Y MAQUILLAJE
# ...

# %%
dates["NUMERO DE EMPLEOS GENERADOS"].sum()
# Out:
# 128

# %%
dates.columns
# Out:
# Index(['CONSECUTIVO', 'NOMBRE', 'TIPO DE EMPRENDIMIENTO', 'AÑO VINCULACIÓN',
#        'EDAD EN AÑOS', 'SECTOR ECONOMICO', 'ESCOLARIDAD', 'EVIDENCIAS',
#        'NUMERO DE EMPLEOS GENERADOS', 'ESTADO'],
#       dtype='object')

# %%
dm.get_dates_shape(dates)
# Out:
# (77, 10)

# %%
dm.get_dates_info(dates)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CONSECUTIVO                  77 non-null     int64
#  1   NOMBRE                       77 non-null     object
#  2   TIPO DE EMPRENDIMIENTO       77 non-null     object
#  3   AÑO VINCULACIÓN              77 non-null     int64
#  4   EDAD EN AÑOS                 77 non-null     int32
#  5   SECTOR ECONOMICO             77 non-null     object
#  6   ESCOLARIDAD                  77 non-null     object
#  7   EVIDENCIAS                   77 non-null     object
#  8   NUMERO DE EMPLEOS GENERADOS  77 non-null     int64
#  9   ESTADO                       77 non-null     object
# dtypes: int32(1), int64(3), object(6)
# memory usage: 5.8+ KB
