# %%
import pandas as pd
import dates_module as dt


date = dt.load_archive("5m_Sales_Records.csv","csv")

# %%
dt.get_dates_info(date)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000000 entries, 0 to 4999999
# Data columns (total 14 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Region          object
#  1   Country         object
#  2   Item Type       object
#  3   Sales Channel   object
#  4   Order Priority  object
#  5   Order Date      object
#  6   Order ID        int64
#  7   Ship Date       object
#  8   Units Sold      int64
#  9   Unit Price      float64
#  10  Unit Cost       float64
#  11  Total Revenue   float64
#  12  Total Cost      float64
#  13  Total Profit    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 534.1+ MB

# %%
date.head(10)
# Out:
#                          Region       Country        Item Type Sales Channel  \
# 0         AUSTRALIA AND OCEANIA         Palau  Office Supplies        Online
# 1                        EUROPE        Poland        Beverages        Online
# 2                 NORTH AMERICA        Canada           Cereal        Online
# 3                        EUROPE       Belarus           Snacks        Online
# 4  MIDDLE EAST AND NORTH AFRICA          Oman           Cereal       Offline
# 5            SUB-SAHARAN AFRICA  Burkina Faso  Office Supplies        Online
# 6                        EUROPE    Montenegro    Personal Care        Online
# 7  MIDDLE EAST AND NORTH AFRICA    Azerbaijan        Cosmetics       Offline
# 8            SUB-SAHARAN AFRICA   South Sudan          Clothes       Offline
# 9                 NORTH AMERICA     Greenland    Personal Care        Online
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# ...

# %%
dt.get_dates_shape(date)
# Out:
# (5000000, 15)

# %%
date["Total Test"] = date["Units Sold"] * 2

# %%
date.to_csv("new_file_name.csv")

# %%
date.Region = date.Region.str.upper()

# %%
date = date.loc[(date["Sales Channel"] == "Online") & (date["Order Priority"] == "C") & (date["Units Sold"] <= 2000)]

# %%
dt.get_dates_shape(date)
# Out:
# (124900, 14)

# %%
dt.get_dates_info(date)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 124900 entries, 3 to 4999991
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Region          124900 non-null  object
#  1   Country         124900 non-null  object
#  2   Item Type       124900 non-null  object
#  3   Sales Channel   124900 non-null  object
#  4   Order Priority  124900 non-null  object
#  5   Order Date      124900 non-null  object
#  6   Order ID        124900 non-null  int64
#  7   Ship Date       124900 non-null  object
#  8   Units Sold      124900 non-null  int64
#  9   Unit Price      124900 non-null  float64
#  10  Unit Cost       124900 non-null  float64
#  11  Total Revenue   124900 non-null  float64
#  12  Total Cost      124900 non-null  float64
#  13  Total Profit    124900 non-null  float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 14.3+ MB

# %%
date.head(10)
# Out:
#                            Region          Country        Item Type  \
# 3                          Europe          Belarus           Snacks
# 48                         Europe           Poland        Cosmetics
# 51                         Europe      Switzerland             Meat
# 67                         Europe         Portugal          Clothes
# 68                         Europe   Czech Republic          Clothes
# 117         Australia and Oceania  Solomon Islands        Cosmetics
# 158            Sub-Saharan Africa            Gabon    Personal Care
# 188            Sub-Saharan Africa          Namibia        Beverages
# 228  Middle East and North Africa            Syria  Office Supplies
# 316  Middle East and North Africa             Oman          Clothes
#
#     Sales Channel Order Priority  Order Date   Order ID  Ship Date  \
# 3          Online              C   1/19/2014  954955518  2/27/2014
# 48         Online              C    2/2/2015  897440803  3/13/2015
# ...
